# %% [markdown]
# # Session 2  -- Control Statements and Loops

# %% [markdown]
# ##Conditional execution
#
# Decision-making statements in programming languages decide the direction of the flow of program execution.
#
# In Python, if-else elif statement is used for decision making

# %% [markdown]
# ### if statement
#
# It is used to decide whether a certain statement or block of statements will be executed or not i.e if a certain condition is true then a block of statement is executed otherwise not.
# ![](https://i.imgur.com/dNOszyg.jpg)
#
#
# ```
# Syntax:
# if condition:
#     Body of if
# ```

# %%
x=2
if x<0:
    print(x)

# %%
x=-5
if x<0:
    print(x)
    print("Hi Buddy!")
print("Out of if statement")
# Out:
# -5
# Hi Buddy!
# Out of if statement

# %% [markdown]
# ### if-else
#
# We can use the else statement with if statement to execute a block of code when the condition is false.
#
# ![](https://i.imgur.com/UzlKXuT.jpg)
#
# ```
# Syntax:
# if condition:
#     Body of if
# else:
#     Body of else
# ```

# %%
x=6
if x%2==0:
    print(x," is even")
else:
    print(x," is odd")
print("Finally I got it predicted as an EVEN or ODD Number")
# Out:
# 6  is even
# Finally I got it predicted as an EVEN or ODD Number

# %%
x = 40
if x>35:
    print(x,"is greater that 35")
else:
    print(x,"is less than or equal to 35")
# Out:
# 40 is greater that 35

# %%
x=['banana','mango','apple']
y=['cat','dog','goat']
z=input('Enter the name of fruit or pet here: ').lower()

if z in x:
    print(z,'is a fruit')

if z in y:
    print(z,'is a pet')
else:
    print('Enter valid name')
# Out:
# Enter the name of fruit or pet here: dog
# dog is a pet

# %% [markdown]
# ### if-elif-else
#
# The if statements are executed from the top down. As soon as one of the conditions controlling the if is true, the statement associated with that if is executed, and the rest of the ladder is bypassed. If none of the conditions is true, then the final else statement will be executed.
#
#
# ![](https://i.imgur.com/fKDw3WU.jpg)
#
#
# ```
# Syntax:
# if condition:
#     Body of if
#
# elif condition:
#     Body of if
#
# else:
#     Body of else
# ```

# %%
x=['banana','mango','apple']
y=['cat','dog','goat']
z=input('Enter the name of fruit or pet here: ')
z1=z.lower()
if z1 in x:
    print(z.capitalize(),'is a fruit')

elif z1 in y:
    print(z.capitalize(),'is a pet')
else:
    print('Enter valid name')
# Out:
# Enter the name of fruit or pet here: xyz
# Enter valid name

# %%
x=15
y=16
z=8

if x<y and y>z:
    print('x is smaller than y and y is greater than z')


elif x>y and y>z:
    print('x is greater than y and y is greater than z')

elif x<y and x>z:
    print('x is greater than z and y is greater than x')

elif x<y and x<z:
    print('x is smaller than y and z')

elif z>y and z>x:
    print('z is greater than x and y')
# Out:
# x is smaller than y and y is greater than z

# %% [markdown]
# In the above example you can observe that two conditions are True i.e. (x<y and x<z) and  (z>y and z>x) but the result is printed for first condtion only. In if elif else statement preferance is given to first true condition.
#
# else block is not compulsory when writing conditional statement.
#
# Any condion can not be written along with else.

# %%
a=2
b=6

if a>3:
    print('a is greater')
elif b<a:
    print('b is smaller')

else b>a:
    print('b is greater')
# Out:
# b is greater

# %%
a=2
b=6

if a>3:
    print('a is greater')
elif b<a:
    print('b is smaller')

else:
    print('b is greater')
# Out:
# b is greater

# %% [markdown]
# ### Nested if
# One if statement inside another if statement is called Nested if statement. The structure and flow of execution can be assumed as shown below
#
# ![](https://i.imgur.com/xOTsQz2.jpg)
# ```
# Syntax:
#
# if condition:
#     if Nested Condition:
#         body of nested if
#     else:
#         body of nested else
#
# else:
#     body of else

# %%
num1 = 5
if (num1 != 0):
    if(num1 > 0):
        print("num1 is a positive number")
    else:
        print("num1 is a negative number")
else:
    print("num1 is neither positive nor negative")
# Out:
# num1 is a positive number

# %%
num1 = -5
if (num1 != 0):
    if(num1 > 0):
        print("num1 is a positive number")
    else:
        print("num1 is a negative number")
else:
    print("num1 is neither positive nor negative")
# Out:
# num1 is a negative number

# %%
num1 = 0
if (num1 != 0):
    if(num1 > 0):
        print("num1 is a positive number")
    else:
        print("num1 is a negative number")
else:
    print("num1 is neither positive nor negative")
# Out:
# num1 is neither positive nor negative

# %%
a_number = 16

# %%
if a_number % 2 == 0:
    print("{} is even".format(a_number))
    if a_number % 3 == 0:
        print("{} is also divisible by 3".format(a_number))
    else:
        print("{} is not divisible by 3".format(a_number))
else:
    print("{} is odd".format(a_number))
    if a_number % 5 == 0:
        print("{} is also divisible by 5".format(a_number))
    else:
        print("{} is not divisible by 5".format(a_number))
# Out:
# 16 is even
# 16 is not divisible by 3

# %% [markdown]
# ### Non-Boolean Conditions
#
# Note that conditions do not necessarily have to be booleans. In fact, a condition can be any value. The value is converted into a boolean automatically using the `bool` operator. This means that falsy values like `0`, `''`, `{}`, `[]`, etc. evaluate to `False` and all other values evaluate to `True`.

# %%
if '':
    print('The condition evaluted to True')
else:
    print('The condition evaluted to False')
# Out:
# The condition evaluted to False

# %%
if 'Hello':
    print('The condition evaluted to True')
else:
    print('The condition evaluted to False')
# Out:
# The condition evaluted to True

# %%
if { 'a': 34 }:
    print('The condition evaluted to True')
else:
    print('The condition evaluted to False')
# Out:
# The condition evaluted to True

# %%
if None:
    print('The condition evaluted to True')
else:
    print('The condition evaluted to False')
# Out:
# The condition evaluted to False

# %% [markdown]
# ### Shorthand `if` conditional expression
#
# A frequent use case of the `if` statement involves testing a condition and setting a variable's value based on the condition.

# %% [markdown]
# \Python provides a shorter syntax, which allows writing such conditions in a single line of code. It is known as a *conditional expression*, sometimes also referred to as a *ternary operator*. It has the following syntax:
#
# ```
# x = true_value if condition else false_value
# ```
#
# It has the same behavior as the following `if`-`else` block:
#
# ```
# if condition:
#     x = true_value
# else:
#     x = false_value
# ```
#
# Let's try it out for the example above.

# %%
a_number = 13

if a_number % 2 == 0:
    parity = 'even'
else:
    parity = 'odd'

print('The number {} is {}.'.format(a_number, parity))
# Out:
# The number 13 is odd.

# %%
a_number=14

# %%
parity = 'even' if a_number % 2 == 0 else 'odd'

# %%
print('The number {} is {}.'.format(a_number, parity))
# Out:
# The number 14 is even.

# %% [markdown]
# ### Statements and Expressions
#
# The conditional expression highlights an essential distinction between *statements* and *expressions* in Python.
#
# > **Statements**: A statement is an instruction that can be executed. Every line of code we have written so far is a statement e.g. assigning a variable, calling a function, conditional statements using `if`, `else`, and `elif`, loops using `for` and `while` etc.
#
# > **Expressions**: An expression is some code that evaluates to a value. Examples include values of different data types, arithmetic expressions, conditions, variables, function calls, conditional expressions, etc.
#
#
# Most expressions can be executed as statements, but not all statements are expressions. For example, the regular `if` statement is not an expression since it does not evaluate to a value. It merely performs some branching in the code. Similarly, loops and function definitions are not expressions (we'll learn more about these in later sections).
#
# As a rule of thumb, an expression is anything that can appear on the right side of the assignment operator `=`. You can use this as a test for checking whether something is an expression or not. You'll get a syntax error if you try to assign something that is not an expression.

# %%
# if statement
result = if a_number % 2 == 0: 
    'even'
else:
    'odd'
# Out:
#   File "<ipython-input-39-f24978c5423e>", line 2
#     result = if a_number % 2 == 0:
#              ^
# SyntaxError: invalid syntax

# %%
# if expression
result = 'even' if a_number % 2 == 0 else 'odd'

# %%
result
# Out:
# 'even'

# %%
required_brand=input('Enter your Brand from IPhone/Redmi/Samsung: ')
color_choice=input('Choice of color black/red: ')
required_ram= input('Ram required 4GB/8GB')
color_choice_1='red'
color_choice_2='black'
ram_1='4GB'
ram_2='8GB'
brand_1='Redmi'
brand_2='Samsung'

if required_brand==brand_1:
    if color_choice==color_choice_1 and required_ram== ram_1:
        print('Bought Mobile 1')

    elif color_choice==color_choice_2 and required_ram== ram_1:
        print('Bought Mobile 2')
    
    elif color_choice==color_choice_1 and required_ram== ram_2:
        print('Bought Mobile 3')
    
    elif color_choice==color_choice_2 and required_ram== ram_2:
        print('Bought Mobile 4')
    
    else:
        print('Please go to the next shop')
        
elif required_brand==brand_2:
    if color_choice==color_choice_1 and required_ram== ram_1:
        print('Bought Mobile 5')

    elif color_choice==color_choice_2 and required_ram== ram_1:
        print('Bought Mobile 6')
    
    elif color_choice==color_choice_1 and required_ram== ram_2:
        print('Bought Mobile 7')
    
    elif color_choice==color_choice_2 and required_ram== ram_2:
        print('Bought Mobile 8')
    
    else:
        print('Please go to the next shop')

else:
    print('Buy online')
# Out:
# Enter your Brand from IPhone/Redmi/Samsung: Iphone
# Choice of color black/red: black
# Ram required 4GB/8GB8GB
# Buy online

# %% [markdown]
# ## `for` loops
#
# ![](https://i.imgur.com/6o6D2GS.jpg)
#
# A `for` loop is used for iterating or looping over sequences, i.e., lists, tuples, dictionaries, strings, and *ranges*. For loops have the following syntax:
#
# ```
# for value in sequence:
#     statement(s)
# ```
#
# The statements within the loop are executed once for each element in `sequence`. Here's an example that prints all the element of a list.
#
#
#
# ![](https://i.imgur.com/SVLCI2J.jpg)

# %%
days = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday']

for day in days:
    print(day)
# Out:
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday

# %% [markdown]
# ### Iterating using `range` and `enumerate`
#
# The `range` function is used to create a sequence of numbers that can be iterated over using a `for` loop. It can be used in 3 ways:
#
# * `range(n)` - Creates a sequence of numbers from `0` to `n-1`
# * `range(a, b)` - Creates a sequence of numbers from `a` to `b-1`
# * `range(a, b, step)` - Creates a sequence of numbers from `a` to `b-1` with increments of `step`
#
# Let's try it out.

# %%
for i in range(3):
    print(i)
# Out:
# 0
# 1
# 2

# %%
for i in range(3):
    print(i,end='')
# Out:
# 012

# %%
for i in range(3):
    print(i,end=' ')
# Out:
# 0 1 2

# %%
a_list = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday']

for i in range(len(a_list)):
    print('The value at position {} is {}.'.format(i+1, a_list[i]))
# Out:
# The value at position 1 is Monday.
# The value at position 2 is Tuesday.
# The value at position 3 is Wednesday.
# The value at position 4 is Thursday.
# The value at position 5 is Friday.

# %% [markdown]
# Another way to achieve the same result is by using the `enumerate` function
#
# 1.   List item
#
#
# with `a_list` as an input, which returns a tuple containing the index and the corresponding element.

# %%
for i, val in enumerate(a_list):
    print('The value at position {} is {}.'.format(i, val))
# Out:
# The value at position 0 is Monday.
# The value at position 1 is Tuesday.
# The value at position 2 is Wednesday.
# The value at position 3 is Thursday.
# The value at position 4 is Friday.

# %%
# Looping over a tuple
for fruit in ('Apple', 'Banana', 'Guava'):
    print("Here's a fruit:", fruit)
# Out:
# Here's a fruit: Apple
# Here's a fruit: Banana
# Here's a fruit: Guava

# %%
# Looping over a dictionary
person = {
    'name': 'John Doe',
    'sex': 'Male',
    'age': 32,
    'married': True
}

for key in person:
    print("Key:", key, ",", "Value:", person[key])
# Out:
# Key: name , Value: John Doe
# Key: sex , Value: Male
# Key: age , Value: 32
# Key: married , Value: True

# %% [markdown]
# ### `break`, `continue` and `pass` statements
#
# Similar to `while` loops, `for` loops also support the `break` and `continue` statements. `break` is used for breaking out of the loop and `continue` is used for skipping ahead to the next iteration.
#
# ![](https://i.imgur.com/30ZduuC.jpg)

# %%
weekdays = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday']

# %%
for day in weekdays:
    print('Today is {}'.format(day))
    if (day == 'Wednesday'):
        print("I don't work beyond Wednesday!")
        break
# Out:
# Today is Monday
# Today is Tuesday
# Today is Wednesday
# I don't work beyond Wednesday!

# %%
for day in weekdays:
    if (day == 'Wednesday'):
        print("I don't work on Wednesday!")
        continue
    print('Today is {}'.format(day))
# Out:
# Today is Monday
# Today is Tuesday
# I don't work on Wednesday!
# Today is Thursday
# Today is Friday

# %%
for day in weekdays:
    pass

# %%
for i in 'Python Training Session':
    if i=='P':
        pass
    elif i=='y':
        continue
    elif i=='g':
        break
    else:
        print(i)
# Out:
# t
# h
# o
# n
#
# T
# r
# a
# i
# n
# i
# n

# %% [markdown]
# ## Assignment Operators for increment and decrement
# ![](https://i.imgur.com/Lp8oiav.png)

# %%
x=10
x=x+1
print(x)
# Out:
# 11

# %%
x+=1           # x=x+1
print(x)
# Out:
# 12

# %%
x+=10           #x=x+10
print(x)
# Out:
# 22

# %%
x-=2    # x= x-2
print(x)
# Out:
# 20

# %%
x*=2   # x=x*2
print(x)
# Out:
# 40

# %%
x/=2  # x=x/2
print(x)
# Out:
# 20.0

# %%
x//=3  # x= x//3
print(x)
# Out:
# 6.0

# %%
x%=4 # x=x%4
print(x)
# Out:
# 2.0

# %%
x**=3
x
# Out:
# 64.0

# %%
a=1
a+=1
a
# Out:
# 2

# %% [markdown]
# ## while loop
#
# ![](https://i.imgur.com/ZNt0lbV.jpg)
#
# ## Iteration with `while` loops
#
# Another powerful feature of programming languages, closely related to branching, is running one or more statements multiple times. This feature is often referred to as *iteration* on *looping*, and there are two ways to do this in Python: using `while` loops and `for` loops.
#
# `while` loops have the following syntax:
#
# ```
# while condition:
#     statement(s)
# ```
#
# Statements in the code block under `while` are executed repeatedly as long as the `condition` evaluates to `True`. Generally, one of the statements under `while` makes some change to a variable that causes the condition to evaluate to `False` after a certain number of iterations.
#
# Let's try to calculate the factorial of `100` using a `while` loop. The factorial of a number `n` is the product (multiplication) of all the numbers from `1` to `n`, i.e., `1*2*3*...*(n-2)*(n-1)*n`.

# %%
while True:
    print(1)

# %%
for i in range(1):
    print(1)

# %% [markdown]
# ```
# counter
# while condition:
#     block
#     update the counter
# ```

# %%
i=0
while i<5:
    print(1)
    i=i+1
# Out:
# 1
# 1
# 1
# 1
# 1

# %%
i=0
sum=0
while i<=5:
    sum=sum+i
    i+=1
print(sum)
# Out:
# 15

# %%
# Sum of natural numbers   5    == 5+4=9+3=12+2=14+1=15
num = int(input())

if num < 0:
    print("Enter a positive number")

    
else:
    sum = 0
   # use while loop to iterate until zero
    while(num > 0):
        sum += num      # sum=sum+num
        num -= 1
        
    print("The sum is", sum)
# Out:
# 20
# The sum is 210

# %%
# Simple Calculator

print("Select operation.")
print("1.Add")
print("2.Subtract")
print("3.Multiply")
print("4.Divide")

while True:
    # take input from the user
    choice = input("Enter choice(1/2/3/4): ")

    # check if choice is one of the four options
    if choice in ('1', '2', '3', '4'):
        num1 = float(input("Enter first number: "))
        num2 = float(input("Enter second number: "))

        if choice == '1':
            print(num1, "+", num2, "=", (num1 + num2))

        elif choice == '2':
            print(num1, "-", num2, "=", (num1 - num2))

        elif choice == '3':
            print(num1, "*", num2, "=", (num1 * num2))

        elif choice == '4':
            print(num1, "/", num2, "=", (num1 / num2))
        
        # check if user wants another calculation
        # break the while loop if answer is no
        next_calculation = input("Let's do next calculation? (yes/no): ")
        if next_calculation == "yes":
            continue
        else:
            break
    
    else:
        print("Invalid Input")
# Out:
# Select operation.
# 1.Add
# 2.Subtract
# 3.Multiply
# 4.Divide
# Enter choice(1/2/3/4): 1
# Enter first number: 2
# Enter second number: 3
# 2.0 + 3.0 = 5.0
# Let's do next calculation? (yes/no): yes
# Enter choice(1/2/3/4): 5
# Invalid Input
# Enter choice(1/2/3/4): 6
# Invalid Input
# Enter choice(1/2/3/4): 2
# Enter first number: 6
# Enter second number: 5
# 6.0 - 5.0 = 1.0
# Let's do next calculation? (yes/no): no

# %% [markdown]
# Here's another example that uses two `while` loops to create an interesting pattern.

# %%
line = '*'
max_length = 10

while len(line) < max_length:
    print(line)
    line += "*"
    
while len(line) > 0:
    print(line)
    line = line[:-1]
# Out:
# *
# **
# ***
# ****
# *****
# ******
# *******
# ********
# *********
# **********
# *********
# ********
# *******
# ******
# *****
# ****
# ***
# **
# *

# %%
# Prints all letters except 'e' and 's'
i = 0
a = 'impressed'

while i < len(a):
	if a[i] == 'm' or a[i] == 'p':
		i += 1
		continue
		
	print('Current Letter :', a[i])
	i += 1
# Out:
# Current Letter : i
# Current Letter : r
# Current Letter : e
# Current Letter : s
# Current Letter : s
# Current Letter : e
# Current Letter : d

# %%
count = 0                                  # if else, for else, while else, try-except-else
while count < 5:
   print (count, " is  less than 5")
   count = count + 1
else:
   print (count, " is not less than 5")
# Out:
# 0  is  less than 5
# 1  is  less than 5
# 2  is  less than 5
# 3  is  less than 5
# 4  is  less than 5
# 5  is not less than 5

# %%
#break the loop as soon it sees 'o'
#or 'i'
i = 0
a = 'boardinfinity'
 
while i < len(a):
    if a[i] == 'd' or a[i] == 'i':
        i += 1
        break
         
    print('Current Letter :', a[i])
    i += 1
# Out:
# Current Letter : b
# Current Letter : o
# Current Letter : a
# Current Letter : r

# %%
# A sample use of increasing the variable value by one.
count=0
count+=1
count=count+1
print('The Value of Count is',count)
 
# A Sample Python program to show loop (unlike many
# other languages, it doesn't use ++)
# this is for increment operator here start = 1,
# stop = 5 and step = 1(by default)
print("INCREMENTED FOR LOOP")
for i in range(0, 5):
   print(i)
 
# this is for increment operator here start = 5,
# stop = -1 and step = -1
print("\n DECREMENTED FOR LOOP")
for i in range(4, -1, -1):
   print(i)
# Out:
# The Value of Count is 2
# INCREMENTED FOR LOOP
# 0
# 1
# 2
# 3
# 4
#
#  DECREMENTED FOR LOOP
# 4
# 3
# 2
# 1
# 0

# %% [markdown]
# ## Exception Handeling
# ![](https://i.imgur.com/ArWPIkw.jpg)
#
# Error in Python can be of two types i.e. Syntax errors and Exceptions. Errors are the problems in a program due to which the program will stop the execution.
# On the other hand, exceptions are raised when some internal events occur which changes the normal flow of the program.
#
# **Try and Except Statement**
#
# Try and except statements are used to catch and handle exceptions in Python.
# statements that can raise exceptions are kept inside the try clause and the statements that handle the exception are written inside except clause.

# %%
# eligiblity check for voting
age=int(input('Enter your Age: '))

if age>=18:
    print('You are eligible for voting')
else:
    print('You are not eligible for voting')
# Out:
# Enter your Age: p
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-34-d92957cec4e1> in <module>
#       1 # eligiblity check for voting
# ----> 2 age=int(input('Enter your Age: '))
#       3
#       4 if age>=18:
#       5     print('You are eligible for voting')
#
# ValueError: invalid literal for int() with base 10: 'p'

# %%
try:
    age=int(input('Enter your Age: '))

    if age >= 18:
        print('You are eligible for voting')
    else:
        print('You are not eligible for voting')
        
except:
    print('Enter valid input')
# Out:
# Enter your Age: p
# Enter valid input

# %%
10/0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-35-e574edb36883> in <module>
# ----> 1 10/0
#
# ZeroDivisionError: division by zero

# %% [markdown]
# ### Catching Specific Exception
#
# A try statement can have more than one except clause, to specify handlers for different exceptions. Please note that at most one handler will be executed. For example, we can add IndexError in the above code. The general syntax for adding specific exceptions are –
#
# ```
# try:
#     # statement(s)
# except IndexError:
#     # statement(s)
# except ValueError:
#     # statement(s)
# ```

# %%
try:
    age=int(input('Enter your Age: '))

    if age >= 18:
        print('You are eligible for voting')
    else:
        print('You are not eligible for voting')


except ValueError:
    
    print('Enter only integers')

except:
    print('Enter valid input')
# Out:
# Enter your Age: 2o
# Enter only integers

# %% [markdown]
# ### Try with Else Clause
#
# In python, you can also use the else clause on the try-except block which must be present after all the except clauses. The code enters the else block only if the try clause does not raise an exception.

# %%
try:
    operartion= input(""" enter 1 for +
    enter 2 for -
    enter 3 fpr *
    enter 4 for /""")

    num1,num2=map(float,input().split())

    if operartion=='1':
        print(num1+num2)
    
    elif operartion=='2':
        print(num1-num2)
    
    elif operartion=='3':
        print(num1*num2)
    
    elif operartion=='4':
        print(num1/num2)
except ZeroDivisionError:
    print('Enter num2 value other than zero')
    
except ValueError:
    print('Enter numbers only')   
    
except:
    print('enter valid syntax')
    
else:
    print('enter valid sequence of operation')
# Out:
#  enter 1 for +
#     enter 2 for -
#     enter 3 fpr *
#     enter 4 for /5
# 2 3
# enter valid sequence of operation

# %% [markdown]
# ### Multiple Exception
# We can use a tuple of values to specify multiple exceptions in an except clause. Here is an example

# %%
a=input('Enter the value of a')
b=input('Enter the value of b')
try:
    if int(a)<int(b):
        print('a is smaller than b, ',(int(b)/int(a)))
    else:
        print('a is greater than b, ',(int(a)-int(b)))


except (ValueError, ZeroDivisionError):
   # handle multiple exceptions
   # ValueError and ZeroDivisionError
    
    print('Enter correct values')

except:
   # handle all other exceptions
   pass
# Out:
# Enter the value of a0
# Enter the value of b6
# Enter correct values

# %% [markdown]
# ### try and finally
# The try statement in Python can have an optional finally clause. This clause is executed no matter what, and is generally used to release external resources.

# %%
a=3
b=6
c=0

try:
    if c>10:
        print('c is greater')
    else:
        print('C is not greater')
except ZeroDivisionError:
    print('This is exception')
else:
    print('Enter valid number')
finally:
    print('finally I am here')
# Out:
# C is not greater
# Enter valid number
# finally I am here

# %% [markdown]
# ### Raising Exceptions
#
# In Python programming, exceptions are raised when errors occur at runtime. We can also manually raise exceptions using the raise keyword.
#
# We can optionally pass values to the exception to clarify why that exception was raised.

# %%
a = int(input("Enter a positive integer: "))
if a <= 0:
    raise ValueError("That is not a positive number!")
else:
    print('a: ',a)
# Out:
# Enter a positive integer: -6
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-45-e96e664a9704> in <module>
#       1 a = int(input("Enter a positive integer: "))
#       2 if a <= 0:
# ----> 3     raise ValueError("That is not a positive number!")
#       4 else:
#       5     print('a: ',a)
#
# ValueError: That is not a positive number!

# %%
a = int(input("Enter a positive integer: "))
if a <= 0:
    raise ZeroDivisionError("That is not a positive number!")
else:
    print('result: ',a/2)
# Out:
# Enter a positive integer: 0
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-46-e58e3e21daa4> in <module>
#       1 a = int(input("Enter a positive integer: "))
#       2 if a <= 0:
# ----> 3     raise ZeroDivisionError("That is not a positive number!")
#       4 else:
#       5     print('result: ',a/2)
#
# ZeroDivisionError: That is not a positive number!

# %%
# Program to depict Raising Exception

try:
	raise NameError("Hi there") # Raise Error
except NameError:
	print ("An exception")
	raise # To determine whether the exception was raised or not
# Out:
# An exception
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-49-87bf2bdaba1c> in <module>
#       2
#       3 try:
# ----> 4         raise NameError("Hi there") # Raise Error
#       5 except NameError:
#       6         print ("An exception")
#
# NameError: Hi there

# %% [markdown]
# >>> More Examples

# %%
while True:
    try:
        a=float(input("Enter 1st number:"))
        b=float(input("Enter 2nd number:"))
        c=a/b
        print("Division of a=",a,"and b=",b,"is c=",round(c,2))
        break
    except Exception:
        print("Something is wron0g. Please try again.")
# Out:
# Enter 1st number:2
# Enter 2nd number:0
# Something is wrong. Please try again.
# Enter 1st number:5
# Enter 2nd number:6
# Division of a= 5.0 and b= 6.0 is c= 0.83

# %%
while True:
    try:
        a=float(input("Enter 1st number:"))
        b=float(input("Enter 2nd number:"))
        c=a/b
        print("Division of a=",a,"and b=",b,"is c=",round(c,2))
        break
    except ZeroDivisionError:
        print("2nd input cannot be zero. Please try again.")
    except ValueError:
        print("Input must be a number. Please try again.")

# %% [markdown]
# ## PATTERNS IN PYTHON
#
# - Patterns can be printed in python using simple for loops
# - Manipulating the print statements, different number patterns, alphabet patterns, or star patterns can be printed
#
# Types of Patterns:
#
# - Pyramid Pattern
#
# - Number Pattern
#
# - Character Pattern

# %%
def pattern(n):
      k = 2 * n - 2
      for i in range(0,n):
           for j in range(0,k):
               print(end=" ")
           k = k - 1
           for j in range(0, i+1):
                print("*", end=" ")
           print("\r")

pattern(5)
# Out:
#         *
#        * *
#       * * *
#      * * * *
#     * * * * *

# %%
def pattern(n):
      for i in range(0,n):
         for j in range(0, i+1):
              print("* " , end="")
         print("\r")
pattern(5)
# Out:
# *
# * *
# * * *
# * * * *
# * * * * *

# %%
def pattern(n):
      for i in range(0,n):
         for j in range(0, i+1):
              print("-*- " , end="")
         print("\r")
pattern(10)
# Out:
# -*-
# -*- -*-
# -*- -*- -*-
# -*- -*- -*- -*-
# -*- -*- -*- -*- -*-
# -*- -*- -*- -*- -*- -*-
# -*- -*- -*- -*- -*- -*- -*-
# -*- -*- -*- -*- -*- -*- -*- -*-
# -*- -*- -*- -*- -*- -*- -*- -*- -*-
# -*- -*- -*- -*- -*- -*- -*- -*- -*- -*-

# %%
def pattern(n):
      for i in range(0,n):
         for j in range(0, i+1):
              print("10 " , end="")
         print("\r")
pattern(5)
# Out:
# 10
# 10 10
# 10 10 10
# 10 10 10 10
# 10 10 10 10 10

# %%
def pattern(n):
      for i in range(0,n):
         for j in range(0, i+1):
              print("ubaid " , end="")
         print("\r")
pattern(5)
# Out:
# ubaid
# ubaid ubaid
# ubaid ubaid ubaid
# ubaid ubaid ubaid ubaid
# ubaid ubaid ubaid ubaid ubaid

# %% [markdown]
# **Charecter pattern**

# %%
chr(65)
# Out:
# 'd'

# %%
def pattern(n):
      x = 65
      for i in range(0, n):
        ch = chr(x)
        x += 1
        for j in range(0, i + 1):
            print(ch, end=" ")
        print("\r")
pattern(10)
# Out:
# A
# B B
# C C C
# D D D D
# E E E E E
# F F F F F F
# G G G G G G G
# H H H H H H H H
# I I I I I I I I I
# J J J J J J J J J J
